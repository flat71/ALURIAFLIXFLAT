# %% [markdown]
# <a href="https://colab.research.google.com/github/flat71/ALURIAFLIXFLAT/blob/main/Matem%C3%A1tica_computacional(.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
(3**(1/2))**2
# Out:
# 2.9999999999999996

# %%
import numpy
numpy.sqrt(3)**2==3
# Out:
# np.False_

# %%
import numpy
numpy.sqrt(3)**2
# Out:
# np.float64(2.9999999999999996)

# %%
a=3242
print('%.10'% a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1914438557.py in <cell line: 0>()
#       1 a=3242
# ----> 2 print('%.10'% a)
#
# ValueError: incomplete format

# %%
a=0.23241
print('%.4e' % a)
# Out:
# 2.3241e-01

# %%
print('%.4e' % 0.000054)
# Out:
# 5.4000e-05

# %%
5.4323e+05
# Out:
# 543230.0

# %%
import sys
sys.float_info.min
# Out:
# 2.2250738585072014e-308

# %%
import sys
sys.float_info.max
# Out:
# 1.7976931348623157e+308

# %%
import sys
sys.float_info.epsilon
# Out:
# 2.220446049250313e-16

# %%
a=2.3421e+02
b=3.5154e+02
c=a+b
print('%.10e'% c)
# Out:
# 5.8575000000e+02

# %%
a=2.3421e+02
b=3.5154e+04
c=a+b
print('%.10e'% c)
# Out:
# 3.5388210000e+04

# %%
a=2.3421e+02
b=3.5154e+02
c=a/b
print('%.10e'% c)
# Out:
# 6.6623997269e-01

# %%
for n in range(10):
print(n)
# Out:
#   File "/tmp/ipython-input-1722900910.py", line 2
#     print(n)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %%
abs(123450.10-123400)
# Out:
# 50.10000000000582

# %%
abs(123450.10-123400)/abs(123450.10)
# Out:
# 0.00040583199203569556
